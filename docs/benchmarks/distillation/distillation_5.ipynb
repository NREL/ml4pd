# %% [markdown]
# # 5 Components Data

# %%
import numpy as np
import time

from ml4pd import components
from ml4pd_utils.utils import prep_dist
from ml4pd.aspen_units import Distillation
from ml4pd.streams import MaterialStream

input_molecules = prep_dist.get_mol_labels()
components.set_components(input_molecules['name'].to_list())

raw_data = prep_dist.get_test_val_data(compositions=[5], dates=['220803', '220821'], chemistries=['ketone', 'vfa'])
data = prep_dist.add_name_columns(raw_data, input_molecules[['name', 'mol']])
data = prep_dist.add_flow_perc(data)
data = prep_dist.rename_flowrate_columns(data)

# %% [markdown]
# ## Benchmark Data Info

# %%
input_molecules.T
# Out:
#          0        1           2            3           4            5   \
# name  water  acetone  2-butanone  3-pentanone  3-hexanone  4-heptanone
# mol     H2O   C3-ONE      C4-ONE       C5-ONE      C6-ONE       C7-ONE
#
#               6           7           8             9             10  \
# name  4-octanone  5-nonanone  5-decanone  6-undecanone  6-dodecanone
# mol       C8-ONE      C9-ONE     C10-ONE       C11-ONE       C12-ONE
#
#                  11               12               13           15  \
# name  6-tridecanone  7-tetradecanone  8-pentadecanone  acetic acid
# mol         C13-ONE          C14-ONE          C15-ONE     C2-VFA-1
#
#                   16           17              18               19  \
# name  propionic acid  lactic acid  n-butyric acid  isobutyric acid
# mol         C3-VFA-1     C3-VFA-2        C4-VFA-1         C4-VFA-2
#
#                  20              21               22               23  \
# name  succinic acid  n-valeric acid  isovaleric acid  n-hexanoic acid
# mol        C4-VFA-3        C5-VFA-1         C5-VFA-2         C6-VFA-1
#
#                     24               25
# name  n-heptanoic acid  n-octanoic acid
# mol           C7-VFA-1         C8-VFA-1

# %%
raw_data.describe().T
# Out:
#                    count          mean           std            min  \
# flowrate_feed_A  20000.0      0.199983      0.118690   6.980000e-06
# flowrate_feed_B  20000.0      0.201280      0.119440   5.629000e-05
# flowrate_feed_C  20000.0      0.200902      0.119361   2.970000e-06
# flowrate_feed_D  20000.0      0.199275      0.119452   3.600000e-07
# flowrate_feed_E  20000.0      0.198560      0.119057   5.533000e-05
# ratio_reflux     20000.0      6.435446      6.388346   1.000130e-02
# ratio_boilup     20000.0      6.451441      6.402725   1.000825e-02
# no_stages        20000.0     25.937450     10.441709   2.000000e+00
# pressure_atm     20000.0     11.013329      9.646763   1.000076e-01
# vapor_fraction   20000.0      0.000000      0.000000   0.000000e+00
# feed_pressure    20000.0     11.013330      9.646763   1.000086e-01
# feed_stage       20000.0     14.849400      9.854820   1.000000e+00
# flowrate_bott_A  20000.0      0.116562      0.121545  8.813600e-135
# flowrate_dist_A  20000.0      0.083421      0.110636  3.686646e-192
# flowrate_bott_B  20000.0      0.118119      0.123006   3.605370e-98
# flowrate_dist_B  20000.0      0.083119      0.110589  2.374956e-193
# flowrate_bott_C  20000.0      0.117537      0.122092  3.243705e-115
# flowrate_dist_C  20000.0      0.083274      0.110193  7.267095e-191
# flowrate_bott_D  20000.0      0.116745      0.121970  9.910446e-124
# flowrate_dist_D  20000.0      0.082592      0.110123  7.482385e-218
# flowrate_bott_E  20000.0      0.114929      0.121433  6.524492e-148
# flowrate_dist_E  20000.0      0.083701      0.110830  6.756445e-178
# duty_condensor   19997.0 -88620.301749  93065.169083  -7.089535e+05
# duty_reboiler    19997.0  93960.612316  95587.606122  -2.614584e+05
# temp_dist        20000.0    191.887762     93.265066  -6.347664e+01
# temp_feed        20000.0    220.050162     95.246437   1.249288e+01
# temp_bott        20000.0    273.174271    112.708110   1.268440e+01
#
#                            25%           50%            75%            max
# flowrate_feed_A       0.104156      0.197229       0.280663       0.800957
# flowrate_feed_B       0.107165      0.198513       0.281438       0.792575
# flowrate_feed_C       0.105593      0.198683       0.280597       0.876337
# flowrate_feed_D       0.103065      0.195981       0.279485       0.810572
# flowrate_feed_E       0.103093      0.196413       0.280503       0.795694
# ratio_reflux          0.394860      4.292628      11.668729      19.999177
# ratio_boilup          0.393612      4.283122      11.780911      19.999795
# no_stages            19.000000     28.000000      35.000000      40.000000
# pressure_atm          1.597764      8.826406      19.321675      29.999425
# vapor_fraction        0.000000      0.000000       0.000000       0.000000
# feed_pressure         1.597765      8.826407      19.321676      29.999426
# feed_stage            6.000000     14.000000      22.000000      41.000000
# flowrate_bott_A       0.001489      0.079850       0.205137       0.719872
# flowrate_dist_A       0.000012      0.023459       0.145806       0.763315
# flowrate_bott_B       0.001653      0.083536       0.205971       0.782064
# flowrate_dist_B       0.000006      0.021885       0.145236       0.748012
# flowrate_bott_C       0.001639      0.082439       0.205900       0.893043
# flowrate_dist_C       0.000010      0.022422       0.148290       0.748199
# flowrate_bott_D       0.001627      0.080386       0.203325       0.810572
# flowrate_dist_D       0.000007      0.022104       0.144290       0.826444
# flowrate_bott_E       0.001310      0.078013       0.200952       0.795694
# flowrate_dist_E       0.000004      0.022441       0.147754       0.729162
# duty_condensor  -139083.968237 -57452.175624  -11391.901801  305696.881257
# duty_reboiler     12982.818436  64909.481046  147013.201381  713849.739131
# temp_dist           115.207356    203.203051     266.995062    1235.075040
# temp_feed           141.750092    236.124449     298.947957     454.516744
# temp_bott           192.726465    288.576729     352.678666    2081.084900

# %% [markdown]
# ## Time Benchmark

# %%
times = []
for i in range(0, 10):
    start_time = time.time()
    feed_stream = MaterialStream(stream_type="feed")(
        vapor_fraction=data['vapor_fraction'].to_list(),
        pressure=data['feed_pressure'].to_list(),
        molecules=prep_dist.get_name_columns(data).to_dict('list'),
        flowrates=prep_dist.get_flowrate_columns(data).to_dict('list'),
    )
    
    dist_col = Distillation(
        no_stages = data['no_stages'].to_list(),
        feed_stage =  data['feed_stage'].to_list(),
        pressure = data['pressure_atm'].to_list(),
        reflux_ratio = data['ratio_reflux'].to_list(),
        boilup_ratio = data['ratio_boilup'].to_list(),
        verbose=False,
        fillna=False
    )

    bott_stream, dist_stream = dist_col(feed_stream)
    
    times.append(time.time() - start_time)

ordered_data = prep_dist.sort_targets_by_weight(data, feed_stream._mw_idx)

average = np.mean(times).round(2)
std = np.std(times).round(2)

print(f"{len(data)} data pts take {average} +/- {std} seconds to predict.")
# Out:
# 20000 data pts take 6.14 +/- 0.96 seconds to predict.

# %% [markdown]
# ## Classifier Benchmark

# %%
ok_idx = np.array(ordered_data[ordered_data['Status'] == 'OK'].index)
prep_dist.plot_confusion_matrix(ordered_data, dist_col.status)

# %% [markdown]
# ## Flowrates Benchmark

# %%
prep_dist.plot_flow(
    all_true=ordered_data,
    y_pred=bott_stream.flow,
    data_slice={
        'Status': 'OK',
    }
)

# %% [markdown]
# ## Duty Benchmark

# %%
prep_dist.plot_duty(all_true=ordered_data, dist_col=dist_col, data_slice={"Status": "OK"})

# %% [markdown]
# ## Temperature Benchmark

# %%
prep_dist.plot_temp(all_true=ordered_data, bott_stream=bott_stream.temperature, dist_stream=dist_stream.temperature, data_slice={'Status': 'OK'})

# %% [markdown]
# ## Mean Absolute Errors

# %%
prep_dist.evaluate_flow(
    all_true=ordered_data, 
    y_pred=bott_stream.flow,
    metric='mae',
    data_slice={"Status": "OK"}
)
# Out:
#    flowrate_bott_A  flowrate_bott_B  flowrate_bott_C  flowrate_bott_D  \
# 0         0.008092         0.014717         0.018041         0.015435
#
#    flowrate_bott_E      mean  count
# 0         0.008879  0.013033  16697

# %%
prep_dist.evaluate_duty(
    all_true=ordered_data, 
    dist_col=dist_col, 
    metric='mae',
    data_slice={"Status": "OK"}
)
# Out:
#    condensor_duty  reboiler_duty         mean  count
# 0     8456.313549    9252.730796  8854.522172  16697

# %%
prep_dist.evaluate_temp(
    all_true=ordered_data, 
    bott_stream=bott_stream.temperature, 
    dist_stream=dist_stream.temperature, 
    data_slice={'Status': 'OK'},
    metric="mae"
)
# Out:
#    bott_temp  dist_temp       mean  count
# 0  14.363853   8.159196  11.261524  16697
