# %% [markdown]
# # 4 Components Data

# %%
import numpy as np
import time

from ml4pd import components
from ml4pd_utils.utils import prep_dist
from ml4pd.aspen_units import Distillation
from ml4pd.streams import MaterialStream

input_molecules = prep_dist.get_mol_labels()
components.set_components(input_molecules['name'].to_list())

raw_data = prep_dist.get_test_val_data(compositions=[4], dates=['220803', '220821'], chemistries=['ketone', 'vfa'])
data = prep_dist.add_name_columns(raw_data, input_molecules[['name', 'mol']])
data = prep_dist.add_flow_perc(data)
data = prep_dist.rename_flowrate_columns(data)

# %% [markdown]
# ## Benchmark Data Info

# %%
input_molecules.T
# Out:
#          0        1           2            3           4            5   \
# name  water  acetone  2-butanone  3-pentanone  3-hexanone  4-heptanone
# mol     H2O   C3-ONE      C4-ONE       C5-ONE      C6-ONE       C7-ONE
#
#               6           7           8             9             10  \
# name  4-octanone  5-nonanone  5-decanone  6-undecanone  6-dodecanone
# mol       C8-ONE      C9-ONE     C10-ONE       C11-ONE       C12-ONE
#
#                  11               12               13           15  \
# name  6-tridecanone  7-tetradecanone  8-pentadecanone  acetic acid
# mol         C13-ONE          C14-ONE          C15-ONE     C2-VFA-1
#
#                   16           17              18               19  \
# name  propionic acid  lactic acid  n-butyric acid  isobutyric acid
# mol         C3-VFA-1     C3-VFA-2        C4-VFA-1         C4-VFA-2
#
#                  20              21               22               23  \
# name  succinic acid  n-valeric acid  isovaleric acid  n-hexanoic acid
# mol        C4-VFA-3        C5-VFA-1         C5-VFA-2         C6-VFA-1
#
#                     24               25
# name  n-heptanoic acid  n-octanoic acid
# mol           C7-VFA-1         C8-VFA-1

# %%
raw_data.describe().T
# Out:
#                    count           mean           std            min  \
# flowrate_feed_A  20000.0       0.249592      0.147578   1.819000e-05
# flowrate_feed_B  20000.0       0.248045      0.146732   5.581000e-05
# flowrate_feed_C  20000.0       0.251517      0.146990   7.594000e-05
# flowrate_feed_D  20000.0       0.250845      0.146865   4.256000e-05
# ratio_reflux     20000.0       6.366363      6.384597   1.001588e-02
# ratio_boilup     20000.0       6.951498      6.334806   1.005892e-02
# no_stages        20000.0      25.776450     10.420183   2.000000e+00
# pressure_atm     20000.0      10.518098      9.447364   1.000668e-01
# vapor_fraction   20000.0       0.000000      0.000000   0.000000e+00
# feed_pressure    20000.0      10.518099      9.447364   1.000678e-01
# feed_stage       20000.0      14.683600      9.787532   1.000000e+00
# flowrate_bott_A  20000.0       0.135139      0.145473  5.096552e-119
# flowrate_dist_A  20000.0       0.114258      0.136330   0.000000e+00
# flowrate_bott_B  20000.0       0.136224      0.145549  4.230274e-159
# flowrate_dist_B  20000.0       0.111956      0.135141  2.164293e-164
# flowrate_bott_C  20000.0       0.137917      0.146570  1.538019e-152
# flowrate_dist_C  20000.0       0.113683      0.136705  4.909511e-161
# flowrate_bott_D  20000.0       0.137871      0.146765  2.162268e-128
# flowrate_dist_D  20000.0       0.112952      0.135961  1.143877e-181
# duty_condensor   19999.0  -95887.980441  95413.628010  -1.626714e+06
# duty_reboiler    19999.0  102021.348513  96621.122594  -5.847137e+04
# temp_dist        20000.0     196.422296     93.784304  -1.442447e+02
# temp_feed        20000.0     220.951570     95.899717   1.042466e+01
# temp_bott        20000.0     275.747208    115.125234   1.185702e+01
#
#                            25%           50%            75%            max
# flowrate_feed_A       0.132592      0.248141       0.346164       0.952012
# flowrate_feed_B       0.131733      0.246154       0.345179       0.948755
# flowrate_feed_C       0.136617      0.250040       0.346490       0.925147
# flowrate_feed_D       0.135823      0.247728       0.346023       0.902403
# ratio_reflux          0.351862      4.169228      11.629124      19.997514
# ratio_boilup          0.863287      5.193692      12.402489      19.998452
# no_stages            19.000000     28.000000      34.000000      40.000000
# pressure_atm          1.445966      8.065254      18.366311      29.996934
# vapor_fraction        0.000000      0.000000       0.000000       0.000000
# feed_pressure         1.445967      8.065255      18.366312      29.996935
# feed_stage            6.000000     14.000000      22.000000      41.000000
# flowrate_bott_A       0.001628      0.089915       0.236739       0.924335
# flowrate_dist_A       0.000255      0.055334       0.200609       0.804903
# flowrate_bott_B       0.001549      0.090567       0.238357       0.911249
# flowrate_dist_B       0.000280      0.051169       0.196833       0.851203
# flowrate_bott_C       0.001489      0.092927       0.240510       0.831021
# flowrate_dist_C       0.000205      0.052319       0.197916       0.891269
# flowrate_bott_D       0.001604      0.092898       0.239930       0.914464
# flowrate_dist_D       0.000178      0.052398       0.198179       0.866137
# duty_condensor  -146084.351846 -65010.681445  -19367.887392   79484.783570
# duty_reboiler     24897.002854  73445.292332  153757.472155  727282.036044
# temp_dist           120.996433    204.671793     271.144456    1180.128070
# temp_feed           143.985692    233.584079     299.160139     488.557034
# temp_bott           198.185639    289.395684     352.508370    3699.783060

# %% [markdown]
# ## Time Benchmark

# %%
times = []
for i in range(0, 10):
    start_time = time.time()
    feed_stream = MaterialStream(stream_type="feed")(
        vapor_fraction=data['vapor_fraction'].to_list(),
        pressure=data['feed_pressure'].to_list(),
        molecules=prep_dist.get_name_columns(data).to_dict('list'),
        flowrates=prep_dist.get_flowrate_columns(data).to_dict('list'),
    )
    
    dist_col = Distillation(
        no_stages = data['no_stages'].to_list(),
        feed_stage =  data['feed_stage'].to_list(),
        pressure = data['pressure_atm'].to_list(),
        reflux_ratio = data['ratio_reflux'].to_list(),
        boilup_ratio = data['ratio_boilup'].to_list(),
        verbose=False,
        fillna=False
    )

    bott_stream, dist_stream = dist_col(feed_stream)
    
    times.append(time.time() - start_time)

ordered_data = prep_dist.sort_targets_by_weight(data, feed_stream._mw_idx)

average = np.mean(times).round(2)
std = np.std(times).round(2)

print(f"{len(data)} data pts take {average} +/- {std} seconds to predict.")
# Out:
# 20000 data pts take 7.28 +/- 1.24 seconds to predict.

# %% [markdown]
# ## Classifier Benchmark

# %%
ok_idx = np.array(ordered_data[ordered_data['Status'] == 'OK'].index)
prep_dist.plot_confusion_matrix(ordered_data, dist_col.status)

# %% [markdown]
# ## Flowrates Benchmark

# %%
prep_dist.plot_flow(
    all_true=ordered_data,
    y_pred=bott_stream.flow,
    data_slice={
        'Status': 'OK',
    }
)

# %% [markdown]
# ## Duty Benchmark

# %%
prep_dist.plot_duty(all_true=ordered_data, dist_col=dist_col, data_slice={"Status": "OK"})

# %% [markdown]
# ## Temperature Benchmark

# %%
prep_dist.plot_temp(all_true=ordered_data, bott_stream=bott_stream.temperature, dist_stream=dist_stream.temperature, data_slice={'Status': 'OK'})

# %% [markdown]
# ## Mean Absolute Errors

# %%
prep_dist.evaluate_flow(
    all_true=ordered_data, 
    y_pred=bott_stream.flow,
    metric='mae',
    data_slice={"Status": "OK"}
)
# Out:
#    flowrate_bott_A  flowrate_bott_B  flowrate_bott_C  flowrate_bott_D  \
# 0         0.011677         0.020839         0.021181         0.013223
#
#       mean  count
# 0  0.01673  17118

# %%
prep_dist.evaluate_duty(
    all_true=ordered_data, 
    dist_col=dist_col, 
    metric='mae',
    data_slice={"Status": "OK"}
)
# Out:
#    condensor_duty  reboiler_duty         mean  count
# 0     8940.979705    9615.971054  9278.475379  17118

# %%
prep_dist.evaluate_temp(
    all_true=ordered_data, 
    bott_stream=bott_stream.temperature, 
    dist_stream=dist_stream.temperature, 
    data_slice={'Status': 'OK'},
    metric="mae"
)
# Out:
#    bott_temp  dist_temp      mean  count
# 0  14.533701   8.330418  11.43206  17118
